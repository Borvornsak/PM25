# %%
import scipy as sp
print('scipy: %s' % sp.__version__)
# numpy
import numpy as np
print('numpy: %s' % np.__version__)
# matplotlib
import matplotlib.pyplot
print('matplotlib: %s' % matplotlib.__version__)
# pandas
import pandas as pd
print('pandas: %s' % pd.__version__)
# scikit-learn
import sklearn 
print('sklearn: %s' % sklearn.__version__)
# statsmodels
import statsmodels as sm
print('statsmodels: %s' % sm.__version__)
# Out:
# scipy: 0.19.1
# numpy: 1.13.3
# matplotlib: 2.1.1
# pandas: 0.22.0
# sklearn: 0.19.1
# statsmodels: 0.8.0

# %%
dataframe = pd.read_json('../pm25_05t.json')
series = pd.Series(data = dataframe['24hr_average_PM2.5 (ug/m3)'].values, index=dataframe['DateTime'].values)
split_point = int(len(series)*0.7)
print('Split dataset at index ',split_point)
dataset, validation = series[0:split_point], series[split_point:]
print('Dataset %d, Validation %d' % (len(dataset), len(validation)))
dataset.to_csv('dataset.csv')
validation.to_csv('validation.csv')
# Out:
# Split dataset at index  954
# Dataset 954, Validation 409

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt

# load data
series = pd.Series.from_csv('dataset.csv')

# prepare data
X = series.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]

# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
    # predict
    yhat = history[-1]
    predictions.append(yhat)
    # observation
    obs = test[i]
    history.append(obs)
    #print('>Predicted=%.3f, Expected=%3.f' % (yhat, obs))
# report performance
mse = mean_squared_error(test, predictions)
rmse = sqrt(mse)
print('RMSE: %.3f' % rmse)
# Out:
# RMSE: 1.029
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/pandas/core/series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)

# %%
#plt.style.use('fivethirtyeight')
series.plot(figsize=(15, 6))
plt.show()

# %%
plt.figure(1)
plt.subplot(211)
series.hist(figsize=(15, 10))
plt.subplot(212)
series.plot(kind='kde')
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# create a differenced series
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return pd.Series(diff)

X = series.values
X = X.astype('float32')
# difference data
hours_in_day = 24
stationary = difference(X, hours_in_day)
stationary.index = series.index[hours_in_day:]
# check if stationary
result = adfuller(stationary)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# save
stationary.to_csv('stationary.csv')
# plot
stationary.plot()
plt.show()
# Out:
# ADF Statistic: -3.847232
# p-value: 0.002459
# Critical Values:
# 	1%: -3.438
# 	5%: -2.865
# 	10%: -2.568
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
from pandas import Series
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot
series = Series.from_csv('stationary.csv')
pyplot.figure(figsize=(15, 10))
pyplot.subplot(211)
plot_acf(series, ax=pyplot.gca())
pyplot.subplot(212)
plot_pacf(series, ax=pyplot.gca())
pyplot.show()
# Out:
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/pandas/core/series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)

# %%
from pandas import Series
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima_model import ARIMA
from math import sqrt

# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return diff

# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

# load data
series = Series.from_csv('dataset.csv')
# prepare data
X = series.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]
# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
	# difference data
	hours_in_day = 24
	diff = difference(history, hours_in_day)
	# predict
	model = ARIMA(diff, order=(1,1,1))
	model_fit = model.fit(trend='nc', disp=0)
	yhat = model_fit.forecast()[0]
	yhat = inverse_difference(history, yhat, hours_in_day)
	predictions.append(yhat)
	# observation
	obs = test[i]
	history.append(obs)
	#print('>Predicted=%.3f, Expected=%3.f' % (yhat, obs))
# report performance
mse = mean_squared_error(test, predictions)
rmse = sqrt(mse)
print('RMSE: %.3f' % rmse)
# Out:
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/pandas/core/series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)
# RMSE: 0.728

# %%
import warnings
from pandas import Series
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error
from math import sqrt
import numpy

# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return numpy.array(diff)

# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

# evaluate an ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	X = X.astype('float32')
	train_size = int(len(X) * 0.50)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		# difference data
		hours_in_day = 24
		diff = difference(history, hours_in_day)
		model = ARIMA(diff, order=arima_order)
		model_fit = model.fit(trend='nc', disp=0)
		yhat = model_fit.forecast()[0]
		yhat = inverse_difference(history, yhat, hours_in_day)
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	mse = mean_squared_error(test, predictions)
	rmse = sqrt(mse)
	return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					mse = evaluate_arima_model(dataset, order)
					if mse < best_score:
						best_score, best_cfg = mse, order
					print('ARIMA%s RMSE=%.3f' % (order,mse))
				except:
					continue
	print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# load dataset
series = Series.from_csv('dataset.csv')
# evaluate parameters
p_values = range(0, 7)
d_values = range(0, 3)
q_values = range(0, 7)
warnings.filterwarnings("ignore")
#evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/pandas/core/series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)
# ARIMA(0, 0, 1) RMSE=7.251
# ARIMA(0, 1, 1) RMSE=1.020
# ARIMA(0, 1, 2) RMSE=0.833
# ARIMA(0, 1, 3) RMSE=0.860
# ARIMA(0, 1, 4) RMSE=0.817
# ARIMA(0, 1, 6) RMSE=0.743
# ARIMA(0, 2, 1) RMSE=0.745
# ARIMA(0, 2, 2) RMSE=0.762
# ARIMA(0, 2, 3) RMSE=0.767
# ARIMA(0, 2, 4) RMSE=0.739
# ARIMA(0, 2, 5) RMSE=0.734
# ARIMA(0, 2, 6) RMSE=0.741
# ARIMA(1, 0, 0) RMSE=1.491
# ARIMA(1, 0, 1) RMSE=1.021
# ARIMA(1, 0, 2) RMSE=0.833
# ARIMA(1, 0, 3) RMSE=0.859
# ARIMA(1, 0, 4) RMSE=0.816
# ARIMA(1, 0, 5) RMSE=0.751
# ARIMA(1, 0, 6) RMSE=0.740
# ARIMA(1, 1, 0) RMSE=0.712
# ARIMA(1, 1, 1) RMSE=0.728
# ARIMA(1, 1, 2) RMSE=0.752
# ARIMA(1, 1, 3) RMSE=0.756
# ARIMA(1, 1, 4) RMSE=0.720
# ARIMA(1, 1, 5) RMSE=0.718
# ARIMA(1, 1, 6) RMSE=0.731
# ARIMA(1, 2, 0) RMSE=0.766
# ARIMA(1, 2, 1) RMSE=0.774
# ARIMA(1, 2, 5) RMSE=0.739
# ARIMA(2, 0, 1) RMSE=0.712
# ARIMA(2, 0, 2) RMSE=0.725
# ARIMA(2, 0, 3) RMSE=0.727
# ARIMA(2, 0, 4) RMSE=0.705
# ARIMA(2, 0, 5) RMSE=0.699
# ARIMA(2, 1, 0) RMSE=0.746
# ARIMA(2, 1, 1) RMSE=0.749
# ARIMA(2, 1, 2) RMSE=0.751
# ARIMA(2, 1, 5) RMSE=0.723
# ARIMA(2, 2, 0) RMSE=0.776
# ARIMA(3, 0, 1) RMSE=0.740
# ARIMA(3, 1, 0) RMSE=0.761
# ARIMA(3, 1, 1) RMSE=0.751
# ARIMA(3, 2, 0) RMSE=0.761
# ARIMA(3, 2, 1) RMSE=0.748
# ARIMA(4, 1, 0) RMSE=0.753
# ARIMA(4, 1, 1) RMSE=0.738
# ARIMA(4, 2, 0) RMSE=0.741
# ARIMA(4, 2, 1) RMSE=0.741
# ARIMA(4, 2, 2) RMSE=0.744
# ARIMA(5, 0, 1) RMSE=0.709
# ARIMA(5, 0, 2) RMSE=0.706
# ARIMA(5, 1, 0) RMSE=0.723
# ARIMA(5, 1, 2) RMSE=0.725
# ARIMA(5, 2, 0) RMSE=0.741
# ARIMA(5, 2, 1) RMSE=0.733
# ARIMA(6, 0, 1) RMSE=0.705
# ARIMA(6, 0, 2) RMSE=0.713
# ARIMA(6, 1, 0) RMSE=0.724
# ARIMA(6, 2, 0) RMSE=0.739
# ARIMA(6, 2, 3) RMSE=0.734
# Best ARIMA(2, 0, 5) RMSE=0.699

# %%
from pandas import Series
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot

# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return diff

# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

# load data
series = Series.from_csv('dataset.csv')
# prepare data
X = series.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]
# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
	# difference data
	hours_in_day = 24
	diff = difference(history, hours_in_day)
	# predict
	model = ARIMA(diff, order=(2,0,5))
	model_fit = model.fit(trend='nc', disp=0)
	yhat = model_fit.forecast()[0]
	yhat = inverse_difference(history, yhat, hours_in_day)
	predictions.append(yhat)
	# observation
	obs = test[i]
	history.append(obs)
# errors
residuals = [test[i]-predictions[i] for i in range(len(test))]
residuals = DataFrame(residuals)
print(residuals.describe())
# plot
pyplot.figure()
pyplot.subplot(211)
residuals.hist(ax=pyplot.gca())
pyplot.subplot(212)
residuals.plot(kind='kde', ax=pyplot.gca())
pyplot.show()
# Out:
#                 0
# count  477.000000
# mean    -0.004175
# std      0.699399
# min     -2.974397
# 25%     -0.297632
# 50%      0.001035
# 75%      0.277983
# max      2.606844

# %%
from pandas import Series
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from matplotlib import pyplot
from sklearn.metrics import mean_squared_error
from math import sqrt

# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return diff

# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

# load data
series = Series.from_csv('dataset.csv')
# prepare data
X = series.values
X = X.astype('float32')
train_size = int(len(X) * 0.50)
train, test = X[0:train_size], X[train_size:]
# walk-forward validation
history = [x for x in train]
predictions = list()
bias = -0.004175
for i in range(len(test)):
	# difference data
	hours_in_day = 24
	diff = difference(history, hours_in_day)
	# predict
	model = ARIMA(diff, order=(2,0,5))
	model_fit = model.fit(trend='nc', disp=0)
	yhat = model_fit.forecast()[0]
	yhat = bias + inverse_difference(history, yhat, hours_in_day)
	predictions.append(yhat)
	# observation
	obs = test[i]
	history.append(obs)
# report performance
mse = mean_squared_error(test, predictions)
rmse = sqrt(mse)
print('RMSE: %.3f' % rmse)
# errors
residuals = [test[i]-predictions[i] for i in range(len(test))]
residuals = DataFrame(residuals)
print(residuals.describe())
# plot
pyplot.figure()
pyplot.subplot(211)
residuals.hist(ax=pyplot.gca())
pyplot.subplot(212)
residuals.plot(kind='kde', ax=pyplot.gca())
pyplot.show()
# Out:
# RMSE: 0.699
#                   0
# count  4.770000e+02
# mean  -2.424994e-07
# std    6.993986e-01
# min   -2.970222e+00
# 25%   -2.934569e-01
# 50%    5.209624e-03
# 75%    2.821575e-01
# max    2.611019e+00

# %%
from pandas import Series
from statsmodels.tsa.arima_model import ARIMA
from scipy.stats import boxcox
import numpy

# monkey patch around bug in ARIMA class
def __getnewargs__(self):
	return ((self.endog),(self.k_lags, self.k_diff, self.k_ma))

ARIMA.__getnewargs__ = __getnewargs__

# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return diff

# load data
series = Series.from_csv('dataset.csv')
# prepare data
X = series.values
X = X.astype('float32')
# difference data
hours_in_day = 24
diff = difference(X, hours_in_day)
# fit model
model = ARIMA(diff, order=(2,0,5))
model_fit = model.fit(trend='nc', disp=0)
# bias constant, could be calculated from in-sample mean residual
bias = -0.004175
# save model
model_fit.save('model.pkl')
numpy.save('model_bias.npy', [bias])

# %%
from pandas import Series
from statsmodels.tsa.arima_model import ARIMAResults
import numpy

# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

series = Series.from_csv('dataset.csv')
hours_in_day = 24
model_fit = ARIMAResults.load('model.pkl')
bias = numpy.load('model_bias.npy')
yhat = float(model_fit.forecast()[0])
yhat = bias + inverse_difference(series.values, yhat, hours_in_day)
print('Predicted: %.3f' % yhat)
# Out:
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/pandas/core/series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)
# Predicted: 34.096

# %%
from pandas import Series
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima_model import ARIMAResults
from sklearn.metrics import mean_squared_error
from math import sqrt
import numpy

# create a differenced series
def difference(dataset, interval=1):
	diff = list()
	for i in range(interval, len(dataset)):
		value = dataset[i] - dataset[i - interval]
		diff.append(value)
	return diff

# invert differenced value
def inverse_difference(history, yhat, interval=1):
	return yhat + history[-interval]

# load and prepare datasets
dataset = Series.from_csv('dataset.csv')
X = dataset.values.astype('float64')
history = [x for x in X]
hours_in_day = 24
validation = Series.from_csv('validation.csv')
y = validation.values.astype('float64')
# load model
model_fit = ARIMAResults.load('model.pkl')
bias = numpy.load('model_bias.npy')
# make first prediction
predictions = list()
yhat = float(model_fit.forecast()[0])
yhat = bias + inverse_difference(history, yhat, hours_in_day)
predictions.append(yhat)
history.append(y[0])
print('>Predicted=%.3f, Expected=%3.f' % (yhat, y[0]))
# rolling forecasts
for i in range(1, len(y)):
    # difference data
    hours_in_day = 24
    diff = difference(history, hours_in_day)
    # predict
    model = ARIMA(diff, order=(2,0,5))
        model_fit = model.fit(trend='nc', disp=0)
        yhat = model_fit.forecast()[0]
        yhat = bias + inverse_difference(history, yhat, hours_in_day)
        predictions.append(yhat)
        # observation
        obs = y[i]
        history.append(obs)
        print('>Predicted=%.3f, Expected=%3.f, %d/%d' % (yhat, obs, i, len(y)))
    
# report performance
mse = mean_squared_error(y, predictions)
rmse = sqrt(mse)
print('RMSE: %.3f' % rmse)
pyplot.plot(y)
pyplot.plot(predictions, color='red')
pyplot.show()
# Out:
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/pandas/core/series.py:2890: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)
# >Predicted=34.096, Expected= 34
# >Predicted=31.757, Expected= 33, 1/409
# >Predicted=32.698, Expected= 33, 2/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=34.558, Expected= 33, 3/409
# >Predicted=34.020, Expected= 33, 4/409
# >Predicted=33.542, Expected= 33, 5/409
# >Predicted=32.075, Expected= 33, 6/409
# >Predicted=34.698, Expected= 33, 7/409
# >Predicted=31.836, Expected= 33, 8/409
# >Predicted=30.241, Expected= 33, 9/409
# >Predicted=32.642, Expected= 33, 10/409
# >Predicted=33.476, Expected= 33, 11/409
# >Predicted=32.277, Expected= 33, 12/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=36.065, Expected= 33, 13/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=34.523, Expected= 33, 14/409
# >Predicted=33.288, Expected= 33, 15/409
# >Predicted=33.776, Expected= 33, 16/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=32.802, Expected= 33, 17/409
# >Predicted=32.266, Expected= 33, 18/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=33.114, Expected= 33, 19/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=33.335, Expected= 33, 20/409
# >Predicted=33.346, Expected= 33, 21/409
# >Predicted=32.976, Expected= 33, 22/409
# >Predicted=32.548, Expected= 33, 23/409
# >Predicted=33.198, Expected= 33, 24/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted
409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=52.563, Expected= 53, 100/409
# >Predicted=53.754, Expected= 53, 101/409
# >Predicted=52.907, Expected= 53, 102/409
# >Predicted=50.756, Expected= 53, 103/409
# >Predicted=54.403, Expected= 54, 104/409
# >Predicted=52.816, Expected= 56, 105/409
# >Predicted=57.485, Expected= 58, 106/409
# >Predicted=60.223, Expected= 60, 107/409
# >Predicted=60.770, Expected= 63, 108/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=64.948, Expected= 65, 109/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=66.243, Expected= 66, 110/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=67.191, Expected= 67, 111/409
# >Predicted=68.213, Expected= 67, 112/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=67.798, Expected= 67, 113/409
# >Predicted=65.768, Expected= 67, 114/409
# >Predicted=66.895, Expected= 67, 115/409
# >Predicted=66.928, Expected= 67, 116/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=66.079, Expected= 67, 117/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=66.589, Expected= 67, 118/409
# >Predicted=66.868, Expected= 67, 119/409
# >Predicted=67.034, Expected= 67, 120/409
# >Predicted=67.551, Expected= 67, 121/409
# >Predicted=67.311, Expected= 69, 122/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=69.700, Expected= 71, 123/409
# >Predicted=71.920, Expected= 73, 124/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=74.134, Expected= 73, 125/409
# >Predicted=73.880, Expected= 71, 126/409
# >Predicted=69.952, Expected= 69, 127/409
# >Predicted=68.656, Expected= 68, 128/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=67.356, Expected= 66, 129/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=65.685, Expected= 65, 130/409
# >Predicted=64.232, Expected= 65, 131/409
# >Predicted=64.941, Expected= 65, 132/409
# >Predicted=65.046, Expected= 66, 133/409
# >Predicted=66.526, Expected= 67, 134/409
# >Predicted=67.994, Expected= 69, 135/409
# >Predicted=68.594, Expected= 69, 136/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=68.819, Expected= 69, 137/409
# >Predicted=69.412, Expected= 69, 138/409
# >Predicted=68.239, Expected= 69, 139/409
# >Predicted=68.627, Expected= 68, 140/409
# >Predicted=67.410, Expected= 67, 141/409
# >Predicted=66.137, Expected= 65, 142/409
# >Predicted=63.212, Expected= 62, 143/409
# >Predicted=60.039, Expected= 60, 144/409
# >Predicted=58.638, Expected= 58, 145/409
# >Predicted=57.522, Expected= 58, 146/409
# >Predicted=58.838, Expected= 58, 147/409
# >Predicted=59.021, Expected= 58, 148/409
# >Predicted=57.439, Expected= 58, 149/409
# >Predicted=55.532, Expected= 58, 150/409
# >Predicted=57.380, Expected= 57, 151/409
# >Predicted=55.784, Expected= 56, 152/409
# >Predicted=55.336, Expected= 55, 153/409
# >Predicted=54.708, Expected= 53, 154/409
# >Predicted=52.912, Expected= 52, 155/409
# >Predicted=51.526, Expected= 51, 156/409
# >Predicted=51.964, Expected= 51, 157/409
# >Predicted=50.800, Expected= 51, 158/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=51.060, Expected= 50, 159/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=49.424, Expected= 50, 160/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=49.368, Expected= 50, 161/409
# >Predicted=49.342, Expected= 50, 162/409
# >Predicted=49.622, Expected= 50, 163/409
# >Predicted=49.211, Expected= 49, 164/409
# >Predicted=48.757, Expected= 49, 165/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=47.290, Expected= 48, 166/409
# >Predicted=47.162, Expected= 48, 167/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=47.611, Expected= 47, 168/409
# >Predicted=46.984, Expected= 47, 169/409
# >Predicted=49.410, Expected= 47, 170/409
# >Predicted=47.952, Expected= 48, 171/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=47.795, Expected= 47, 172/409
# >Predicted=47.340, Expected= 47, 173/409
# >Predicted=46.025, Expected= 47, 174/409
# >Predicted=46.098, Expected= 46, 175/409
# >Predicted=46.514, Expected= 46, 176/409
# >Predicted=45.781, Expected= 46, 177/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=45.076, Expected= 45, 178/409
# >Predicted=44.475, Expected= 45, 179/409
# >Predicted=44.946, Expected= 45, 180/409
# >Predicted=45.230, Expected= 45, 181/409
# >Predicted=45.049, Expected= 45, 182/409
# >Predicted=44.965, Expected= 45, 183/409
# >Predicted=45.178, Expected= 45, 184/409
# >Predicted=44.751, Expected= 45, 185/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=44.746, Expected= 45, 186/409
# >Predicted=44.577, Expected= 45, 187/409
# >Predicted=44.421, Expected= 45, 188/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=44.924, Expected= 45, 189/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=44.585, Expected= 44, 190/409
# >Predicted=44.022, Expected= 44, 191/409
# >Predicted=43.732, Expected= 44, 192/409
# >Predicted=44.158, Expected= 44, 193/409
# >Predicted=44.703, Expected= 45, 194/409
# >Predicted=45.327, Expected= 45, 195/409
# >Predicted=44.585, Expected= 45, 196/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=44.763, Expected= 45, 197/409
# >Predicted=44.744, Expected= 45, 198/409
# >Predicted=44.385, Expected= 44, 199/409
# >Predicted=44.165, Expected= 44, 200/409
# >Predicted=43.628, Expected= 44, 201/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=42.632, Expected= 42, 202/409
# >Predicted=41.854, Expected= 42, 203/409
# >Predicted=41.476, Expected= 41, 204/409
# >Predicted=40.753, Expected= 41, 205/409
# >Predicted=40.730, Expected= 41, 206/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=40.436, Expected= 40, 207/409
# >Predicted=39.555, Expected= 40, 208/409
# >Predicted=39.431, Expected= 39, 209/409
# >Predicted=39.203, Expected= 39, 210/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=39.615, Expected= 39, 211/409
# >Predicted=39.617, Expected= 39, 212/409
# >Predicted=39.100, Expected= 39, 213/409
# >Predicted=38.477, Expected= 39, 214/409
# >Predicted=38.794, Expected= 39, 215/409
# >Predicted=39.385, Expected= 39, 216/409
# >Predicted=39.765, Expected= 39, 217/409
# >Predicted=39.489, Expected= 40, 218/409
# >Predicted=39.803, Expected= 40, 219/409
# >Predicted=40.093, Expected= 40, 220/409
# >Predicted=39.469, Expected= 40, 221/409
# >Predicted=39.968, Expected= 40, 222/409
# >Predicted=40.377, Expected= 41, 223/409
# >Predicted=40.768, Expected= 41, 224/409
# >Predicted=40.656, Expected= 41, 225/409
# >Predicted=39.997, Expected= 41, 226/409
# >Predicted=40.576, Expected= 40, 227/409
# >Predicted=40.597, Expected= 40, 228/409
# >Predicted=40.147, Expected= 40, 229/409
# >Predicted=40.543, Expected= 41, 230/409
# >Predicted=40.659, Expected= 40, 231/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=40.107, Expected= 40, 232/409
# >Predicted=40.471, Expected= 41, 233/409
# >Predicted=41.271, Expected= 41, 234/409
# >Predicted=41.045, Expected= 41, 235/409
# >Predicted=40.523, Expected= 40, 236/409
# >Predicted=39.312, Expected= 39, 237/409
# >Predicted=38.860, Expected= 38, 238/409
# >Predicted=37.079, Expected= 37, 239/409
# >Predicted=36.789, Expected= 37, 240/409
# >Predicted=36.317, Expected= 36, 241/409
# >Predicted=35.512, Expected= 35, 242/409
# >Predicted=33.766, Expected= 33, 243/409
# >Predicted=31.664, Expected= 32, 244/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=30.285, Expected= 30, 245/409
# >Predicted=29.711, Expected= 29, 246/409
# >Predicted=27.790, Expected= 28, 247/409
# >Predicted=26.745, Expected= 27, 248/409
# >Predicted=25.864, Expected= 25, 249/409
# >Predicted=24.126, Expected= 24, 250/409
# >Predicted=22.321, Expected= 22, 251/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=20.814, Expected= 21, 252/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=19.622, Expected= 19, 253/409
# >Predicted=18.158, Expected= 18, 254/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=16.042, Expected= 16, 255/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:496: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# >Predicted=15.331, Expected= 15, 256/409
# >Predicted=15.057, Expected= 15, 257/409
# >Predicted=13.873, Expected= 14, 258/409
# >Predicted=13.630, Expected= 13, 259/409
# >Predicted=12.641, Expected= 13, 260/409
# >Predicted=11.631, Expected= 12, 261/409
# >Predicted=11.479, Expected= 12, 262/409
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:584: RuntimeWarning: overflow encountered in exp
#   newparams = ((1-np.exp(-params))/
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:585: RuntimeWarning: overflow encountered in exp
#   (1+np.exp(-params))).copy()
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:585: RuntimeWarning: invalid value encountered in true_divide
#   (1+np.exp(-params))).copy()
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:586: RuntimeWarning: overflow encountered in exp
#   tmp = ((1-np.exp(-params))/
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:587: RuntimeWarning: overflow encountered in exp
#   (1+np.exp(-params))).copy()
# /Users/laamsang/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py:587: RuntimeWarning: invalid value encountered in true_divide
#   (1+np.exp(-params))).copy()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-737766c7e362> in <module>()
#      55
#      56 # report performance
# ---> 57 mse = mean_squared_error(y, predictions)
#      58 rmse = sqrt(mse)
#      59 print('RMSE: %.3f' % rmse)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput)
#     236     """
#     237     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 238         y_true, y_pred, multioutput)
#     239     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#     240                                weights=sample_weight)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/regression.py in _check_reg_targets(y_true, y_pred, multioutput)
#      73
#      74     """
# ---> 75     check_consistent_length(y_true, y_pred)
#      76     y_true = check_array(y_true, ensure_2d=False)
#      77     y_pred = check_array(y_pred, ensure_2d=False)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [409, 263]

# %%
y
# Out:
# array([ 34.12350082,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.02700043,  33.02700043,
#         33.02700043,  33.02700043,  33.61600113,  33.86650085,
#         34.11449814,  34.28649902,  35.14450073,  37.87900162,
#         39.61399841,  42.46300125,  45.21549988,  46.45949936,
#         48.99599838,  49.61100006,  51.39699936,  52.77050018,
#         53.37749863,  54.17399979,  54.87149811,  55.51300049,
#         55.93349838,  57.05350113,  57.1570015 ,  57.37400055,
#         58.04349899,  57.81650162,  56.80799866,  55.56650162,
#         54.5870018 ,  54.18399811,  53.69250107,  53.4355011 ,
#         52.99549866,  52.84199905,  52.61050034,  52.93099976,
#         53.85800171,  55.58349991,  58.02349854,  60.18199921,
#         62.57149887,  64.65100098,  66.13749695,  67.20050049,
#         67.18849945,  66.85350037,  66.94300079,  66.75650024,
#         66.95800018,  67.20800018,  67.44400024,  67.29599762,
#         67.20449829,  67.39499664,  68.76550293,  70.71549988,
#         72.6230011 ,  73.22799683,  71.04850006,  69.44850159,
#         67.85199738,  66.35900116,  65.09600067,  64.90750122,
#         65.09149933,  66.23999786,  67.35050201,  68.71150208,
#         68.95800018,  69.09100342,  68.7480011 ,  68.57749939,
#         67.8259964 ,  66.98549652,  64.96350098,  62.33000183,
#         60.18000031,  58.10150146,  58.15650177,  58.35300064,
#         58.44449997,  58.2859993 ,  57.86249924,  56.7745018 ,
#         56.01750183,  55.04550171,  53.45050049,  52.02799988,
#         51.38299942,  50.89350128,  50.68650055,  50.28649902,
#         49.89300156,  49.69649887,  49.59799957,  49.53649902,
#         49.13650131,  48.73799896,  48.38100052,  47.83449936,
#         47.39799881,  47.34799957,  47.30950165,  47.5909996 ,
#         47.33250046,  46.8445015 ,  46.69100189,  46.44100189,
#         46.1894989 ,  45.87250137,  45.08649826,  44.70500183,
#         44.84700012,  44.75550079,  44.9054985 ,  45.04000092,
#         44.74700165,  44.64550018,  44.50600052,  44.65599823,
#         44.79600143,  44.64250183,  44.38600159,  43.94950104,
#         43.91500092,  44.31299973,  44.65650177,  44.80649948,
#         44.94150162,  44.65000153,  44.59149933,  44.29199982,
#         43.98699951,  43.51399994,  42.42449951,  41.63850021,
#         41.23849869,  40.84349823,  40.59000015,  40.23300171,
