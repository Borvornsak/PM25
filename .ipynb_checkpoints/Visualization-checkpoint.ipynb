# %% [markdown]
# # Visualization

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %% [markdown]
# ## Data loading

# %%
pm25_05t = pd.read_json('pm25_05t.json', dtype='object')
pm25_50t = pd.read_json('pm25_50t.json', dtype='object')
pm25_52t = pd.read_json('pm25_52t.json', dtype='object')
pm25_53t = pd.read_json('pm25_53t.json', dtype='object')
pm25_59t = pd.read_json('pm25_59t.json', dtype='object')
pm25_61t = pd.read_json('pm25_61t.json', dtype='object')
pm25_05t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 0 to 1199
# Data columns (total 3 columns):
# 05t_PM2.5 (ug/m3)    1200 non-null object
# Date                 1200 non-null object
# Time                 1200 non-null object
# dtypes: object(3)
# memory usage: 37.5+ KB

# %%
table_list = [pm25_05t,pm25_50t,pm25_52t,pm25_53t,pm25_59t,pm25_61t]
for table in table_list:
    table['DateTime'] = table[['Date','Time']].apply(lambda row: ' '.join(row), axis=1)
    #table['Date'].astype('datetime64[ns]')
    #table['Time'].astype('datetime64[ns]')
    #table['DateTime'].astype('datetime64[ns]')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-f431540d9e6a> in <module>()
#       1 table_list = [pm25_05t,pm25_50t,pm25_52t,pm25_53t,pm25_59t,pm25_61t]
#       2 for table in table_list:
# ----> 3     table['DateTime'] = table.apply(lambda row: row['Date']+" "+row['Time'], axis=1)
#       4     #table['Date'].astype('datetime64[ns]')
#       5     #table['Time'].astype('datetime64[ns]')
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
#    4879                 return self._apply_broadcast(f, axis)
#
# ...

# %%
pm25_05t
# Out:
#      05t_PM2.5 (ug/m3)       Date      Time
# 0                25.78 2018-01-01  00-00-00
# 1                18.94 2018-01-01  01-00-00
# 2                16.83 2018-01-01  02-00-00
# 3                11.90 2018-01-01  03-00-00
# 4                 9.07 2018-01-01  04-00-00
# 5                10.97 2018-01-01  05-00-00
# 6                 9.97 2018-01-01  06-00-00
# 7                 9.14 2018-01-01  07-00-00
# 8                12.93 2018-01-01  08-00-00
# 9                10.94 2018-01-01  09-00-00
# 10                9.14 2018-01-01  10-00-00
# 11               12.94 2018-01-01  11-00-00
# 12               10.90 2018-01-01  12-00-00
# 13                8.17 2018-01-01  13-00-00
# 14               13.07 2018-01-01  14-00-00
# 15               15.00 2018-01-01  15-00-00
# 16               15.27 2018-01-01  16-00-00
# 17               22.93 2018-01-01  17-00-00
# 18               21.24 2018-01-01  18-00-00
# 19               28.00 2018-01-01  19-00-00
# ...
